# %% [markdown]
# ###### Create a program that allows the user to manage their shopping list. The user should be able to add items to the list, remove items, and view the current list of items.

# %% [markdown]
# ###### Statement:
#
# 1. Create a list to store the shopping items
# 2. Use a while loop to create a menu of options for the user to add, remove, or view items from the list
# 3. Use a for loop to iterate through the list of items and display them to the user
# 4. Use the range() function to limit the number of items that can be added to the list
# 5. Use the list, tuple, set, and dictionary data structures to store and manipulate the shopping items
#
# ###### Instructions:
#
# 1. Create a list named 'shopping_list' to store the items.
# 2. Use a while loop to create a menu of options for the user to add, remove, or view items from the list.
# 3. Use the input() function to prompt the user to make a selection from the menu.
# 4. Use an if-elif-else block to determine the user's selection and perform the corresponding action.
# 5. If the user selects 'add', use the input() function to prompt the user to enter an item to add to the list. Use the range() function to limit the number of items that can be added to the list.
# 6. If the user selects 'remove', use the input() function to prompt the user to enter an item to remove from the list.
# 7. If the user selects 'view', use a for loop to iterate through the list of items and display them to the user.
# 8. Use the list, tuple, set, and dictionary data structures to store and manipulate the shopping items.

# %%
# Creating a list to store items
shopping_list = []

# Defining the maximum number of items that can be on the list
max_list = 5

# Counter for the number of items
item_count = 0

# Using while loop to display the menu 
while True:
    print("1. Add Items")
    print("2. Remove Items")
    print("3. View Items")
    print("4. Exit")
    print()
    
    # User's input
    choice = int(input("Choose an option from 1-4: "))
    print()

    # If-elif-else block to determine the user's selection
    if choice == 1:
        if item_count >= max_list:
            print("You have reached the maximum number of items on the list.")
            print()
        else:
            item = input("Enter an item to add to the list: ").lower()
            print()
            shopping_list.append(item)
            print(f"**{item}** has been successfully added to the list.")
            print()
            item_count += 1
            
    elif choice == 2:
        item_to_remove = input("Enter the item you want to remove from the list: ").lower()
        print()
        if item_to_remove in shopping_list:
            shopping_list.remove(item_to_remove)
            print(f"**{item_to_remove}** has been successfully removed from the list.")
            print()
            item_count -= 1
        else:
            print(f"**{item_to_remove}** is not on the list.")
            print()
            
    elif choice == 3:
        if shopping_list:
            print("Shopping List:")
            for item in shopping_list:
                print(f"- {item}")
        else:
            print("Your shopping list is empty.")
            
    elif choice == 4:
        print("Exiting the menu.")
        break

    # Invalid choice
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")
        print()
# Out:
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# Enter an item to add to the list: hangers
#
# **hangers** has been successfully added to the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# Enter an item to add to the list: soap
#
# **soap** has been successfully added to the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# Enter an item to add to the list: brush
#
# **brush** has been successfully added to the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# Enter an item to add to the list: bucket
#
# **bucket** has been successfully added to the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# Enter an item to add to the list: detergent
#
# **detergent** has been successfully added to the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 1
#
# You have reached the maximum number of items on the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 2
#
# Enter the item you want to remove from the list: soap
#
# **soap** has been successfully removed from the list.
#
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 3
#
# Shopping List:
# - hangers
# - brush
# - bucket
# - detergent
# 1. Add Items
# 2. Remove Items
# 3. View Items
# 4. Exit
#
# Choose an option from 1-4: 4
#
# Exiting the menu.
